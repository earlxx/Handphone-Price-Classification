# %%
# Mengimport Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Memanggil DataSet Handphone
df = pd.read_csv('hp_train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Dapat dilihat bahwa dataset Train terdiri dari 2000 baris dan 21 kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# Melihat tipe data stiap fitur/kolom, dan mengecek data yang kosong

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# Statistik Deskriptif pada setiap kolom yang bernilai Integer/Numeric

# %%
df.price_range.value_counts()
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %% [markdown]
# melihat balance pada label atau kolom target

# %%
plt.figure(figsize=(17,10))
corr=df.corr()
sns.heatmap(corr,annot=True)

# %% [markdown]
# Melihat korelasi fitur dengan label, dapat dilihat bahwa RAM memiliki korelasi yang positif dengan price_range sebesar 0.92

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns='price_range')
y = df.price_range

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,stratify=y,random_state=0)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1600, 20), (400, 20), (1600,), (400,))

# %%
# mengimport library dan algoritma

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn.score(X_test,y_test),knn.score(X_train,y_train)
# Out:
# (0.915, 0.949375)

# %% [markdown]
# Hasil KNN dengan neighbors = 5 terlihat score test sebesar 91%, dan score train sebesar 94%.
# ini menunjukan bahwa model kita tidak overfit

# %% [markdown]
# ## Random Forest

# %%
# Pipeline
numeric_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler',MinMaxScaler())
])

categori_pipe = Pipeline([
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder())
])

# Preprocessor
from sklearn.compose import ColumnTransformer
preproses = ColumnTransformer([
    ('numeric',numeric_pipe,['battery_power','clock_speed','fc','int_memory',
                              'm_dep','mobile_wt','n_cores','pc','px_height','px_width','ram','sc_h','sc_w','talk_time']),
    ('kategori',categori_pipe,['blue','dual_sim','four_g','three_g','touch_screen','wifi'])
])

# Algo Pipeline KNN 
pipeline = Pipeline([
    ('preproses',preproses),
    ('algo',RandomForestClassifier())
])

# PARAMS KNN
params_rf = {
    'algo__n_estimators':[100,150,200],
    'algo__max_depth':[20,50,80],
    'algo__max_features':[0.3,0.6,0.8],
    'algo__min_samples_leaf':[1,5,10]
}


model = RandomizedSearchCV(pipeline,params_rf,cv=3,n_iter=50,n_jobs=-1,verbose=1,random_state=42)
model.fit(X_train,y_train)
print(model.best_params_)
print(model.score(X_train,y_train),model.score(X_test,y_test))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  1.7min finished
# {'algo__n_estimators': 100, 'algo__min_samples_leaf': 1, 'algo__max_features': 0.8, 'algo__max_depth': 50}
# 1.0 0.91

# %% [markdown]
# tuning menggunakan random foret, skor train sebesar 100% , skor test sebesar 91% dengan parameter terbaik adalah n_estimators = 100, min_samples_leaf = 1, max_features = 0.8, max-depth = 50

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
np.argmax(rf.feature_importances_)
tree = pd.Series(rf.feature_importances_,X.columns)
plt.figure(figsize=(10,6))
# plt.axis([0,1,None,None])
plt.barh(X.columns,tree)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# melihat Feature Importance, bahwa RAM tertinggi signifikan disusul dengan battery power dan ukuran.

# %%
# menambah dataset baru
df2 = pd.read_csv("hp_test.csv",index_col='id')
df2.head()
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# id
# 1            1043     1          1.8         1  14       0           5    0.1
# 2             841     1          0.5         1   4       1          61    0.8
# 3            1807     1          2.8         0   1       0          27    0.9
# 4            1546     0          0.5         1  18       1          25    0.5
# 5            1434     0          1.4         0  11       1          49    0.5
#
#     mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# id
# 1         193        3  16        226      1412  3476    12     7          2
# 2         191        5  12        746       857  3895     6     0          7
# 3         186        3   4       1270      1366  2396    17    10         10
# 4          96        8  20        295      1752  3893    10     0          7
# 5         108        6  18        749       810  1773    15     8          7
#
# ...

# %%
# prediksi dataset baru menggunakan model yang sudah dibuat
df2['price_range']=rf.predict(df2)

# %%
# melihat hasil prediksi
df2['price_range']
# Out:
# id
# 1       3
# 2       3
# 3       2
# 4       3
# 5       1
#        ..
# 996     2
# 997     1
# 998     0
# 999     2
# 1000    2
# Name: price_range, Length: 1000, dtype: int64

# %%
# menggabungkan dataset 1 dan 2
df3 = df.append(df2).reset_index()
df3.head()
# Out:
#    index  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0      0            842     0          2.2         0   1       0           7
# 1      1           1021     1          0.5         1   0       1          53
# 2      2            563     1          0.5         1   2       1          41
# 3      3            615     1          2.5         0   0       0          10
# 4      4           1821     1          1.2         0  13       1          44
#
#    m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0    0.6        188  ...         20       756  2549     9     7         19
# 1    0.7        136  ...        905      1988  2631    17     3          7
# 2    0.9        145  ...       1263      1716  2603    11     2          9
# 3    0.8        131  ...       1216      1786  2769    16     8         11
# 4    0.6        141  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
df3.drop(columns='index',inplace=True)

# %%
X = df3.drop(columns='price_range')
y = df3.price_range


X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((2400, 20), (600, 20), (2400,), (600,))

# %%
# Pipeline
numeric_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler',MinMaxScaler())
])

categori_pipe = Pipeline([
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder())
])

# Preprocessor
from sklearn.compose import ColumnTransformer
preproses = ColumnTransformer([
    ('numeric',numeric_pipe,['battery_power','clock_speed','fc','int_memory',
                              'm_dep','mobile_wt','n_cores','pc','px_height','px_width','ram','sc_h','sc_w','talk_time']),
    ('kategori',categori_pipe,['blue','dual_sim','four_g','three_g','touch_screen','wifi'])
])

# Algo Pipeline KNN 
pipeline = Pipeline([
    ('preproses',preproses),
    ('algo',RandomForestClassifier())
])

# PARAMS rf
params_rf = {
    'algo__n_estimators':[100,150,200],
    'algo__max_depth':[20,50,80],
    'algo__max_features':[0.3,0.6,0.8],
    'algo__min_samples_leaf':[1,5,10]
}

model = RandomizedSearchCV(pipeline,params_rf,cv=3,n_iter=50,n_jobs=-1,verbose=1,random_state=42)
model.fit(X_train,y_train)
print(model.best_params_)
# print(model.score(X_train,y_train),model.best_score_,model.score(X_test,y_test))
print ("FINAL SCORE : ", format(model.score(X_test,y_test)*100,'.1f'),'%')
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  2.3min finished
# {'algo__n_estimators': 100, 'algo__min_samples_leaf': 1, 'algo__max_features': 0.8, 'algo__max_depth': 80}
# FINAL SCORE :  92.8 %

# %% [markdown]
# setelah menggabungkan data, terlihat FINAL SCORE sebesar 92.8%
